# %% [markdown]
# <a href="https://colab.research.google.com/github/YazCodes/Deep-Learning-projects/blob/main/IrisLearningRate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iris Learning Rate Exercise
# Exercise to adjust the learning rate of the optimiser

# %% [markdown]
# Load the libraries and prepare the data

# %%
import pandas as pd
from IPython.display import display
from sklearn.datasets import load_iris
from sklearn.preprocessing import normalize
from sklearn.model_selection import train_test_split
from keras import utils
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# get the data
data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)

# Normalise the data
df_norm = normalize(df)

# 2. split the data into train and test
X_train, X_test, Y_train, Y_test = train_test_split(df_norm, data.target, random_state=0)

# one-hot encode the data
Y_train_cat = utils.to_categorical(Y_train)
Y_test_cat = utils.to_categorical(Y_test)

# %% [markdown]
# Create, compile, fit the model and plot the accuracy and loss

# %%
model = Sequential() 
model.add(Dense(units=10, input_dim=4, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
model.summary()

# 1. Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
history = model.fit(
    X_train,    # input training data
    Y_train_cat,    # output training data
    batch_size=10,   # mini-batch gradient descent size
    epochs=125,       # number of iterations over the entire training data
    verbose=1,        # what type of information is printed during training
    validation_data=(X_test, Y_test_cat))  # input test data, output test data

# summarize the history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# summarize the history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Adjust the learning rate of the optimiser
# Instead of specifying the optimiser as a string, you can specify the optimiser as an object.  Specifying the optimiser as a string means that it uses it's default parameters.  By specifying it as an object, you have more flexibility and can change it's parameters.  Implement the optimiser as an object so you can change the learning rate (hint: see [keras optimisers](https://keras.io/api/optimizers)).  As we are using Keras from within tensorflow, you will also need to import tensorflow and reference keras from that.  Then you will be able to access the `optimizers` module as in the Keras documentation.
#
#
#
# ```
# import tensorflow as tf
# tf.keras.optimizers...
# ```

# %% [markdown]
# Set the learning rate to the following values.  You will need to re-create, re-compile and re-fit the model and re-plot the accuracy and loss to try out each learning rate.
#
#
# *   0.0001
# *   0.001
# *   0.01
# *   1

# %%
model = Sequential() 
model.add(Dense(units=10, input_dim=4, activation='relu'))
model.add(Dense(units=10, activation='relu'))
model.add(Dense(units=3, activation='softmax'))
model.summary()

#compile the model 
import tensorflow as tf
opt = tf.keras.optimizers.Adam(learning_rate=0.01) #changing the learning rate 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit the model
history = model.fit(
    X_train,    # input training data
    Y_train_cat,    # output training data
    batch_size=10,   # mini-batch gradient descent size
    epochs=125,       # number of iterations over the entire training data
    verbose=1,        # what type of information is printed during training
    validation_data=(X_test, Y_test_cat))  # input test data, output test data

# summarize the history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# summarize the history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 10)                50
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/125
# 12/12 [==============================] - 1s 22ms/step - loss: 1.1224 - accuracy: 0.3536 - val_loss: 1.1166 - val_accuracy: 0.2368
# Epoch 2/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1084 - accuracy: 0.3135 - val_loss: 1.1041 - val_accuracy: 0.2368
# Epoch 3/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0965 - accuracy: 0.3232 - val_loss: 1.1024 - val_accuracy: 0.2368
# Epoch 4/125
# 12/12 [==============================] - 0s 15ms/step - loss: 1.0921 - accuracy: 0.3710 - val_loss: 1.1034 - val_accuracy: 0.2368
# Epoch 5/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0878 - accuracy: 0.3760 - val_loss: 1.1027 - val_accuracy: 0.2368
# Epoch 6/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0856 - accuracy: 0.3777 - val_loss: 1.1029 - val_accuracy: 0.2368
# Epoch 7/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0903 - accuracy: 0.3248 - val_loss: 1.0996 - val_accuracy: 0.2368
# Epoch 8/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0736 - accuracy: 0.4293 - val_loss: 1.0979 - val_accuracy: 0.2368
# Epoch 9/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0775 - accuracy: 0.3834 - val_loss: 1.0953 - val_accuracy: 0.2368
# Epoch 10/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0709 - accuracy: 0.4043 - val_loss: 1.0944 - val_accuracy: 0.2368
# Epoch 11/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0706 - accuracy: 0.3785 - val_loss: 1.0914 - val_accuracy: 0.2368
# Epoch 12/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0736 - accuracy: 0.3317 - val_loss: 1.0878 - val_accuracy: 0.2368
# Epoch 13/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0590 - accuracy: 0.3974 - val_loss: 1.0850 - val_accuracy: 0.2368
# Epoch 14/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0601 - accuracy: 0.3758 - val_loss: 1.0811 - val_accuracy: 0.2368
# Epoch 15/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0559 - accuracy: 0.3628 - val_loss: 1.0766 - val_accuracy: 0.2368
# Epoch 16/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0507 - accuracy: 0.3578 - val_loss: 1.0729 - val_accuracy: 0.2368
# Epoch 17/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0374 - accuracy: 0.3845 - val_loss: 1.0683 - val_accuracy: 0.3684
# Epoch 18/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0235 - accuracy: 0.5373 - val_loss: 1.0628 - val_accuracy: 0.4737
# Epoch 19/125
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0237 - accuracy: 0.6089 - val_loss: 1.0567 - val_accuracy: 0.5000
# Epoch 20/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0190 - accuracy: 0.6430 - val_loss: 1.0509 - val_accuracy: 0.5000
# Epoch 21/125
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0320 - accuracy: 0.5813 - val_loss: 1.0426 - val_accuracy: 0.5263
# Epoch 22/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.9859 - accuracy: 0.7240 - val_loss: 1.0360 - val_accuracy: 0.5263
# Epoch 23/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9838 - accuracy: 0.6955 - val_loss: 1.0270 - val_accuracy: 0.5263
# Epoch 24/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9701 - accuracy: 0.7060 - val_loss: 1.0170 - val_accuracy: 0.5263
# Epoch 25/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9680 - accuracy: 0.6508 - val_loss: 1.0068 - val_accuracy: 0.5526
# Epoch 26/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9436 - accuracy: 0.7073 - val_loss: 0.9965 - val_accuracy: 0.5789
# Epoch 27/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9284 - accuracy: 0.7000 - val_loss: 0.9857 - val_accuracy: 0.5789
# Epoch 28/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9371 - accuracy: 0.6795 - val_loss: 0.9720 - val_accuracy: 0.5789
# Epoch 29/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9184 - accuracy: 0.6717 - val_loss: 0.9617 - val_accuracy: 0.5789
# Epoch 30/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8948 - accuracy: 0.6803 - val_loss: 0.9500 - val_accuracy: 0.5789
# Epoch 31/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8672 - accuracy: 0.7004 - val_loss: 0.9359 - val_accuracy: 0.5789
# Epoch 32/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8904 - accuracy: 0.6495 - val_loss: 0.9184 - val_accuracy: 0.5789
# Epoch 33/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8472 - accuracy: 0.6899 - val_loss: 0.9029 - val_accuracy: 0.5789
# Epoch 34/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8491 - accuracy: 0.6547 - val_loss: 0.8865 - val_accuracy: 0.5789
# Epoch 35/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7969 - accuracy: 0.7372 - val_loss: 0.8736 - val_accuracy: 0.5789
# Epoch 36/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7879 - accuracy: 0.7258 - val_loss: 0.8545 - val_accuracy: 0.5789
# Epoch 37/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7842 - accuracy: 0.7057 - val_loss: 0.8362 - val_accuracy: 0.5789
# Epoch 38/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7561 - accuracy: 0.7156 - val_loss: 0.8244 - val_accuracy: 0.5789
# Epoch 39/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7527 - accuracy: 0.7004 - val_loss: 0.8023 - val_accuracy: 0.5789
# Epoch 40/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7430 - accuracy: 0.6814 - val_loss: 0.7906 - val_accuracy: 0.5789
# Epoch 41/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7100 - accuracy: 0.7077 - val_loss: 0.7722 - val_accuracy: 0.5789
# Epoch 42/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7114 - accuracy: 0.6842 - val_loss: 0.7611 - val_accuracy: 0.5789
# Epoch 43/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7068 - accuracy: 0.6665 - val_loss: 0.7454 - val_accuracy: 0.5789
# Epoch 44/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6856 - accuracy: 0.6716 - val_loss: 0.7259 - val_accuracy: 0.5789
# Epoch 45/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6521 - accuracy: 0.6999 - val_loss: 0.7095 - val_accuracy: 0.5789
# Epoch 46/125
# 12/12 [==============================] - 0s 14ms/step - loss: 0.6327 - accuracy: 0.7217 - val_loss: 0.6983 - val_accuracy: 0.5789
# Epoch 47/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6352 - accuracy: 0.7008 - val_loss: 0.6864 - val_accuracy: 0.5789
# Epoch 48/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6042 - accuracy: 0.7172 - val_loss: 0.6675 - val_accuracy: 0.5789
# Epoch 49/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5954 - accuracy: 0.7147 - val_loss: 0.6513 - val_accuracy: 0.5789
# Epoch 50/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6040 - accuracy: 0.6970 - val_loss: 0.6449 - val_accuracy: 0.5789
# Epoch 51/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5745 - accuracy: 0.6962 - val_loss: 0.6264 - val_accuracy: 0.5789
# Epoch 52/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5892 - accuracy: 0.6645 - val_loss: 0.6137 - val_accuracy: 0.5789
# Epoch 53/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5652 - accuracy: 0.6953 - val_loss: 0.6070 - val_accuracy: 0.5789
# Epoch 54/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5347 - accuracy: 0.7293 - val_loss: 0.5951 - val_accuracy: 0.5789
# Epoch 55/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5593 - accuracy: 0.6903 - val_loss: 0.5897 - val_accuracy: 0.5789
# Epoch 56/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5203 - accuracy: 0.7268 - val_loss: 0.5766 - val_accuracy: 0.5789
# Epoch 57/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5320 - accuracy: 0.7104 - val_loss: 0.5656 - val_accuracy: 0.5789
# Epoch 58/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5010 - accuracy: 0.7259 - val_loss: 0.5639 - val_accuracy: 0.5789
# Epoch 59/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4952 - accuracy: 0.7133 - val_loss: 0.5554 - val_accuracy: 0.5789
# Epoch 60/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4726 - accuracy: 0.7333 - val_loss: 0.5514 - val_accuracy: 0.5789
# Epoch 61/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4924 - accuracy: 0.6882 - val_loss: 0.5421 - val_accuracy: 0.5789
# Epoch 62/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4966 - accuracy: 0.7032 - val_loss: 0.5313 - val_accuracy: 0.6053
# Epoch 63/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4904 - accuracy: 0.7209 - val_loss: 0.5258 - val_accuracy: 0.6053
# Epoch 64/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.7829 - val_loss: 0.5292 - val_accuracy: 0.5789
# Epoch 65/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4507 - accuracy: 0.7463 - val_loss: 0.5170 - val_accuracy: 0.6053
# Epoch 66/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4276 - accuracy: 0.7751 - val_loss: 0.5172 - val_accuracy: 0.5789
# Epoch 67/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4742 - accuracy: 0.6993 - val_loss: 0.5112 - val_accuracy: 0.6053
# Epoch 68/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.7413 - val_loss: 0.5090 - val_accuracy: 0.5789
# Epoch 69/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4482 - accuracy: 0.7454 - val_loss: 0.4950 - val_accuracy: 0.6579
# Epoch 70/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4957 - accuracy: 0.7431 - val_loss: 0.4919 - val_accuracy: 0.6579
# Epoch 71/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4987 - accuracy: 0.7307 - val_loss: 0.4913 - val_accuracy: 0.6579
# Epoch 72/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4436 - accuracy: 0.7808 - val_loss: 0.4908 - val_accuracy: 0.6316
# Epoch 73/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4541 - accuracy: 0.7426 - val_loss: 0.4865 - val_accuracy: 0.6579
# Epoch 74/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4368 - accuracy: 0.7904 - val_loss: 0.4697 - val_accuracy: 0.7105
# Epoch 75/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4590 - accuracy: 0.8157 - val_loss: 0.4602 - val_accuracy: 0.7632
# Epoch 76/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.8848 - val_loss: 0.4612 - val_accuracy: 0.7368
# Epoch 77/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4370 - accuracy: 0.8420 - val_loss: 0.4635 - val_accuracy: 0.7105
# Epoch 78/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4040 - accuracy: 0.8720 - val_loss: 0.4544 - val_accuracy: 0.7368
# Epoch 79/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4169 - accuracy: 0.8295 - val_loss: 0.4511 - val_accuracy: 0.7368
# Epoch 80/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8715 - val_loss: 0.4549 - val_accuracy: 0.7105
# Epoch 81/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4339 - accuracy: 0.8134 - val_loss: 0.4373 - val_accuracy: 0.7895
# Epoch 82/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3810 - accuracy: 0.9323 - val_loss: 0.4403 - val_accuracy: 0.7632
# Epoch 83/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4195 - accuracy: 0.8759 - val_loss: 0.4256 - val_accuracy: 0.8158
# Epoch 84/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3896 - accuracy: 0.9000 - val_loss: 0.4318 - val_accuracy: 0.7895
# Epoch 85/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.8877 - val_loss: 0.4335 - val_accuracy: 0.7632
# Epoch 86/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.9161 - val_loss: 0.4307 - val_accuracy: 0.7632
# Epoch 87/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3514 - accuracy: 0.8968 - val_loss: 0.4137 - val_accuracy: 0.8158
# Epoch 88/125
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3922 - accuracy: 0.9619 - val_loss: 0.4008 - val_accuracy: 0.8947
# Epoch 89/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3569 - accuracy: 0.9547 - val_loss: 0.4073 - val_accuracy: 0.8158
# Epoch 90/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3719 - accuracy: 0.9376 - val_loss: 0.4121 - val_accuracy: 0.7895
# Epoch 91/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.9307 - val_loss: 0.4142 - val_accuracy: 0.7895
# Epoch 92/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.9336 - val_loss: 0.4032 - val_accuracy: 0.8158
# Epoch 93/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3773 - accuracy: 0.9546 - val_loss: 0.4126 - val_accuracy: 0.7895
# Epoch 94/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3508 - accuracy: 0.9068 - val_loss: 0.4108 - val_accuracy: 0.7895
# Epoch 95/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3531 - accuracy: 0.9251 - val_loss: 0.3925 - val_accuracy: 0.8158
# Epoch 96/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3661 - accuracy: 0.9239 - val_loss: 0.3763 - val_accuracy: 0.9211
# Epoch 97/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3764 - accuracy: 0.9508 - val_loss: 0.3761 - val_accuracy: 0.8947
# Epoch 98/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4012 - accuracy: 0.9713 - val_loss: 0.3861 - val_accuracy: 0.8158
# Epoch 99/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3207 - accuracy: 0.9512 - val_loss: 0.3965 - val_accuracy: 0.7895
# Epoch 100/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3386 - accuracy: 0.9303 - val_loss: 0.3778 - val_accuracy: 0.8684
# Epoch 101/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3491 - accuracy: 0.9481 - val_loss: 0.3840 - val_accuracy: 0.8158
# Epoch 102/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3362 - accuracy: 0.9417 - val_loss: 0.3834 - val_accuracy: 0.8158
# Epoch 103/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3323 - accuracy: 0.9279 - val_loss: 0.3711 - val_accuracy: 0.8684
# Epoch 104/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3563 - accuracy: 0.9281 - val_loss: 0.3640 - val_accuracy: 0.8947
# Epoch 105/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.9667 - val_loss: 0.3681 - val_accuracy: 0.8684
# Epoch 106/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3089 - accuracy: 0.9704 - val_loss: 0.3697 - val_accuracy: 0.8158
# Epoch 107/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3049 - accuracy: 0.9502 - val_loss: 0.3643 - val_accuracy: 0.8684
# Epoch 108/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3456 - accuracy: 0.9338 - val_loss: 0.3495 - val_accuracy: 0.8947
# Epoch 109/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3258 - accuracy: 0.9551 - val_loss: 0.3643 - val_accuracy: 0.8158
# Epoch 110/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3411 - accuracy: 0.9521 - val_loss: 0.3505 - val_accuracy: 0.8947
# Epoch 111/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3138 - accuracy: 0.9672 - val_loss: 0.3497 - val_accuracy: 0.8947
# Epoch 112/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3044 - accuracy: 0.9504 - val_loss: 0.3465 - val_accuracy: 0.8947
# Epoch 113/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2904 - accuracy: 0.9527 - val_loss: 0.3305 - val_accuracy: 0.9211
# Epoch 114/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3004 - accuracy: 0.9893 - val_loss: 0.3455 - val_accuracy: 0.8947
# Epoch 115/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3142 - accuracy: 0.9708 - val_loss: 0.3462 - val_accuracy: 0.8947
# Epoch 116/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2903 - accuracy: 0.9425 - val_loss: 0.3435 - val_accuracy: 0.8947
# Epoch 117/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2822 - accuracy: 0.9671 - val_loss: 0.3419 - val_accuracy: 0.8947
# Epoch 118/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.9872 - val_loss: 0.3237 - val_accuracy: 0.9211
# Epoch 119/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.9751 - val_loss: 0.3297 - val_accuracy: 0.8947
# Epoch 120/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2994 - accuracy: 0.9556 - val_loss: 0.3254 - val_accuracy: 0.8947
# Epoch 121/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2629 - accuracy: 0.9684 - val_loss: 0.3333 - val_accuracy: 0.8947
# Epoch 122/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.9626 - val_loss: 0.3386 - val_accuracy: 0.8684
# Epoch 123/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2850 - accuracy: 0.9507 - val_loss: 0.3151 - val_accuracy: 0.9211
# Epoch 124/125
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2521 - accuracy: 0.9872 - val_loss: 0.3051 - val_accuracy: 0.9211
# Epoch 125/125
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.9781 - val_loss: 0.3093 - val_accuracy: 0.9211
